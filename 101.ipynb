# %% [markdown]
# Import Libraries

# %%
import os
import cv2

import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)

import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

from IPython.display import Image

import sys

np.set_printoptions(threshold=sys.maxsize)

#matplotlib inline

# %% [markdown]
# Download Assets

# %%
# Download Assets
def download_and_unzip(url, save_path):
    print(f"Downloading {url} and extracting assets to {save_path}", end="")

    # Downloading zip file using urllib package.
    urlretrieve(url, save_path)

    try:
        # Extracting the zip file using ZipFile package.
        with ZipFile(save_path) as z:
            # Extract ZIP file contents in the same directory.
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/qhhlqcica1nvtaw/opencv_bootcamp_assets_NB1.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), f"opencv_bootcamp_assets_NB1.zip")

# Download if asset ZIP does not exist.
if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)

# %%
# Display Image Directly
Image(filename="checkerboard_18x18.png")

# %%
# Display 84x84 pixel image
Image(filename="checkerboard_84x84.jpg")

# %%
# Reading images using OpenCV
cb_img = cv2.imread("checkerboard_18x18.png", 0)

if cb_img is None:
    print("Image not found")
else:
    print(cb_img)
    print("Image size (H, W) is:", cb_img.shape)
    print("Data type of image is:", cb_img.dtype)

# %%
if cb_img is None:
    print("Image not found")
else:
    plt.imshow(cb_img)

# %%
if cb_img is None:
    print("Image not found")
else:
    plt.imshow(cb_img, cmap='gray')

# %%
# Read image as gray scale.
cb_img_fuzzy = cv2.imread("checkerboard_fuzzy_18x18.jpg", 0)

# print image
if cb_img_fuzzy is None:
    print("Image not found")
else:
    print(cb_img_fuzzy)
    plt.imshow(cb_img_fuzzy, cmap="gray") # Display image.

# %%
# Read and display image using IPython.display.Image
Image("coca-cola-logo.png")

# %%
# Read in image
coke_img = cv2.imread("coca-cola-logo.png", 1)
if coke_img is not None:
    plt.imshow(coke_img)


if coke_img is not None:
    # Reverse the channels from BGR to RGB
    coke_img_channels_reversed = coke_img[:, :, ::-1]
    #print(coke_img)
    print("Image size (H, W, C) is:", coke_img.shape)
    print("Data type of image is:", coke_img.dtype)
else:
    print("Image not found")

# %%
# display image in BGR format using OpenCV
if coke_img is not None:
    plt.imshow(coke_img_channels_reversed)
else:
    print("Image not found")

# %%
# Splitting and Merging Color Channels
img_NZ_bgr = cv2.imread("New_Zealand_Lake.jpg", cv2.IMREAD_COLOR)
if img_NZ_bgr is not None:
    b, g, r = cv2.split(img_NZ_bgr)

    # show the channels
    plt.figure(figsize=(20, 5))
    plt.subplot(141);
    plt.imshow(b, cmap='Blues')
    plt.title('Blue Channel')
    plt.subplot(142);
    plt.imshow(g, cmap='Greens')
    plt.title('Green Channel')
    plt.subplot(143);
    plt.imshow(r, cmap='Reds')
    plt.title('Red Channel')

else:
    print("Image not found")

# %%
# Splitting and Merging Color Channels
img_NZ_bgr = cv2.imread("New_Zealand_Lake.jpg", cv2.IMREAD_COLOR)
if img_NZ_bgr is not None:
    b, g, r = cv2.split(img_NZ_bgr)

    # show the channels
    plt.figure(figsize=(20, 5))
    plt.subplot(131);
    plt.imshow(b, cmap='Blues')
    plt.title('Blue Channel')
    plt.subplot(132);
    plt.imshow(g, cmap='Greens')
    plt.title('Green Channel')
    plt.subplot(133);
    plt.imshow(r, cmap='Reds')
    plt.title('Red Channel')

else:
    print("Image not found")

# %%
# Splitting and Merging Color Channels
img_NZ_bgr = cv2.imread("New_Zealand_Lake.jpg", cv2.IMREAD_COLOR)
if img_NZ_bgr is not None:
    b, g, r = cv2.split(img_NZ_bgr)

    # show the channels
    plt.figure(figsize=(20, 5))
    plt.subplot(311);
    plt.imshow(b, cmap='Blues')
    plt.title('Blue Channel')
    plt.subplot(312);
    plt.imshow(g, cmap='Greens')
    plt.title('Green Channel')
    plt.subplot(313);
    plt.imshow(r, cmap='Reds')
    plt.title('Red Channel')

else:
    print("Image not found")

# %%
# Merge the channels back together
imgMerged = cv2.merge((b, g, r))
# Show the merged image
plt.subplot(144)
plt.imshow(imgMerged[:,:,::-1])
plt.title('Merged Output')

# %%
# Splitting and Merging Color Channels
img_NZ_bgr = cv2.imread("New_Zealand_Lake.jpg", cv2.IMREAD_COLOR)
if img_NZ_bgr is not None:
    b, g, r = cv2.split(img_NZ_bgr)
    imgMerged = cv2.merge((b, g, r))

    # OpenCV stores color channels in a different order than most other applications. (BGR vs RGB). To display the image correctly, we need to reverse the order of the channels when displaying with matplotlib.
    img_NZ_rgb = cv2.cvtColor(img_NZ_bgr, cv2.COLOR_BGR2RGB)

    # show the channels
    plt.figure(figsize=(20, 5))
    plt.subplot(141);
    plt.imshow(b, cmap='Blues')
    plt.title('Blue Channel')
    plt.subplot(142);
    plt.imshow(g, cmap='Greens')
    plt.title('Green Channel')
    plt.subplot(143);
    plt.imshow(r, cmap='Reds')
    plt.title('Red Channel')
    # Merge the channels back together
    plt.subplot(144)
    plt.imshow(imgMerged[:,:,::-1])
    plt.title('Merged Output')
else:
    print("Image not found")
